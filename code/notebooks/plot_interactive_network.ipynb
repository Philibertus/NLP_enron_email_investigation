# %%
# If your notebook is in the same directory as 'functions' folder
import sys
import pandas as pd
sys.path.append('/Users/leuphi/OneDrive/Philipp/ComputerScience/NLP_enron_email_analysis/code/')

from functions.plot_interactive_network import plot_interactive_network

arnold_inbox_entities_df = pd.read_csv("/Users/leuphi/OneDrive/Philipp/ComputerScience/NLP_enron_email_analysis/data/out/arnold_inbox_entities.csv")
benson_inbox_entities_df = pd.read_csv("/Users/leuphi/OneDrive/Philipp/ComputerScience/NLP_enron_email_analysis/data/out/benson_inbox_entities.csv")
scott_inbox_entities_df = pd.read_csv("/Users/leuphi/OneDrive/Philipp/ComputerScience/NLP_enron_email_analysis/data/out/scott_inbox_entities.csv")
lavorato_inbox_entities_df = pd.read_csv("/Users/leuphi/OneDrive/Philipp/ComputerScience/NLP_enron_email_analysis/data/out/lavorato_inbox_entities.csv")


plot_interactive_network(arnold_inbox_entities_df, min_edge_weight=3, output_file='arnold_inbox_network_graph.html')
plot_interactive_network(benson_inbox_entities_df, min_edge_weight=3, output_file='benson_inbox_network_graph.html')
plot_interactive_network(scott_inbox_entities_df, min_edge_weight=5, output_file='scott_inbox_network_graph.html')
plot_interactive_network(lavorato_inbox_entities_df, min_edge_weight=4, output_file='lavorato_inbox_network_graph.html')
# Out:
# Network Graph Created!
#   - Nodes (people): 32
#   - Edges (connections): 80
#   - Min edge weight: 3
#   - Saved to: arnold_inbox_network_graph.html
# Network Graph Created!
#   - Nodes (people): 58
#   - Edges (connections): 180
#   - Min edge weight: 3
#   - Saved to: benson_inbox_network_graph.html
# Network Graph Created!
#   - Nodes (people): 27
#   - Edges (connections): 72
#   - Min edge weight: 5
#   - Saved to: scott_inbox_network_graph.html
# Network Graph Created!
#   - Nodes (people): 45
#   - Edges (connections): 261
#   - Min edge weight: 4
#   - Saved to: lavorato_inbox_network_graph.html

# %% [markdown]
# Run plot interactive network function on the entities dataframes processed from EMails:
