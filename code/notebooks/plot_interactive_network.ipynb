# %% [markdown]
# Run plot interactive network function on the entities dataframes processed from EMails:

# %%
import ipynb
from functions.plot_interactive_network import plot_interactive_network

plot_interactive_network(benson_inbox_entities_df, min_edge_weight=2, output_file='benson_inbox_network_graph.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import import_ipynb
#       2 from functions.plot_interactive_network import plot_interactive_network
#       4 plot_interactive_network(benson_inbox_entities_df, min_edge_weight=2, output_file='benson_inbox_network_graph.html')
#
# ModuleNotFoundError: No module named 'import_ipynb'
